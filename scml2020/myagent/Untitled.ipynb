# %%
python tutorial.py
# Out:
#   File "<ipython-input-1-e37b45e220a9>", line 1
#     python tutorial.py
#            ^
# SyntaxError: invalid syntax

# %%
run -i tutorial.py

# %%
run -i tutorial.py
# Out:
# /Users/ashe/.local/share/virtualenvs/myagent-eLNCiN_O/lib/python3.8/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# 100%|██████████| 10/10 [00:02<00:00,  4.16it/s]
# <img src="run.gif">
